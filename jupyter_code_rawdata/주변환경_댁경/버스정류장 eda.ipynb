# %%
import pandas as pd

# %%
df = pd.read_csv('./원본_전국_버스정류장_주소_좌표.csv',encoding='euc-kr')

# %%
df
# Out:
#                    버스정류장명      경도(표준)     위도(표준)  시도코드(표준)  시도명(표준)  \
# 0                창신3동주민센터  127.015209  37.578310        11    서울특별시
# 1         종로구민회관.창신동두산아파트  127.015548  37.574087        11    서울특별시
# 2                    동묘역앞  127.015591  37.571681        11    서울특별시
# 3             동묘역.롯데캐슬천지인  127.015807  37.574161        11    서울특별시
# 4                숭인1동주민센터  127.015465  37.578636        11    서울특별시
# ...                   ...         ...        ...       ...      ...
# 1258302  화순해안경기안전센터 사계출장소  126.300200  33.226020        50  제주특별자치도
# 1258303         대정읍 다목적회관  126.267000  33.220960        50  제주특별자치도
# 1258304              동광단지  126.359500  33.313880        50  제주특별자치도
# 1258305          사계어촌체험어장  126.304400  33.227940        50  제주특별자치도
# 1258306     화순환승정류장(안덕농협)  126.335100  33.246640        50  제주특별자치도
#
#          시군구코드(표준) 시군구명(표준)  행정읍면동코드(표준) 행정읍면동명(표준)  법정읍면동코드(표준) 법정읍면동명(표준)  \
# ...

# %%
df = df[['버스정류장명','시도명(표준)','시군구명(표준)','시군구코드(표준)']]

# %%
df['주소'] = df['시도명(표준)']+" "+df['시군구명(표준)']
# Out:
# <ipython-input-20-2db7f6310645>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['주소'] = df['시도명(표준)']+" "+df['시군구명(표준)']

# %%
df = df[['버스정류장명','주소','시군구코드(표준)']]

# %%
df = df.rename({'시군구코드(표준)':'법정동코드'},axis=1)

# %%
df1 = df[:600000]
df2 = df[600000:]

# %%
df.to_csv("./버스정류장")
