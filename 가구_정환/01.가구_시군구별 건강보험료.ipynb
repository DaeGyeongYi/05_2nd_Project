# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json

# %%
csvpath1 = '../Data/가구_Data/raw_Data/시군구_광주_전북_전남_제주_별_보험료분위별_현황_20210912182856.csv'
csvpath2 = '../Data/가구_Data/raw_Data/시군구_대전_세종_충북_충남_별_보험료분위별_현황_20210912182856.csv'
csvpath3 = '../Data/가구_Data/raw_Data/시군구_부산_대구_울산_경북_경남_별_보험료분위별_현황_20210912183612.csv'
csvpath4 = '../Data/가구_Data/raw_Data/시군구_서울_인천_경기_강원_별_보험료분위별_현황_20210912182556.csv'

tb_data1 = pd.read_csv(csvpath1, encoding='cp949')
tb_data2 = pd.read_csv(csvpath2, encoding='cp949')
tb_data3 = pd.read_csv(csvpath3, encoding='cp949')
tb_data4 = pd.read_csv(csvpath4, encoding='cp949')

# %%
tb_data1.head()
# Out:
#    시군구별(1)  보험료분위별(1)      2013     2013.1    2013.2   2013.3     2013.4  \
# 0  시군구별(1)  보험료분위별(1)         계          계         계       직장         직장
# 1  시군구별(1)  보험료분위별(1)        소계         소계        소계       소계         소계
# 2  시군구별(1)  보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)
# 3       광주          계    588246      79882   1357778   384823      82390
# 4       광주        1분위     62886      18098    107772    41771      24564
#
#      2013.5   2013.6     2013.7  ...    2019.5   2019.6     2019.7    2019.8  \
# 0        직장       직장         직장  ...        직장       직장         직장        직장
# 1        소계      근로자        근로자  ...        소계      근로자        근로자       근로자
# 2  적용인구 (명)  가입자 (명)  평균보험료 (원)  ...  적용인구 (명)  가입자 (명)  평균보험료 (원)  적용인구 (명)
# 3    965256   340452      76912  ...   1004512   426445     104259    886302
# 4     84898    41501      24560  ...     72754    44403      32527     72440
#
#     2019.9    2019.10   2019.11   2019.12    2019.13   2019.14
# ...

# %%
tb_data2
# Out:
#      시군구별 보험료분위별 가입자구분별     항목  단위     2013 년     2014 년     2015 년  \
# 0      대전      계      계    세대수  세대   628285.0   645200.0   650349.0
# 1      대전      계      계  평균보험료   원    86319.0    90545.0    92418.0
# 2      대전      계      계   적용인구   명  1451826.0  1469900.0  1442544.0
# 3      대전      계     직장    가입자   명   418221.0   436044.0   446396.0
# 4      대전      계     직장  평균보험료   원    87835.0    93200.0    94023.0
# ...   ...    ...    ...    ...  ..        ...        ...        ...
# 6595  태안군   10분위     공교  평균보험료   원   187917.0   197541.0   205308.0
# 6596  태안군   10분위     공교   적용인구   명      441.0      593.0      742.0
# 6597  태안군   10분위     지역    세대수  세대      579.0      559.0      556.0
# 6598  태안군   10분위     지역  평균보험료   원   260164.0   271278.0   288612.0
# 6599  태안군   10분위     지역   적용인구   명     1415.0     1398.0     1392.0
#
#          2016 년     2017 년     2018 년     2019 년  Unnamed: 12
# 0      664049.0   678495.0   695169.0   713038.0          NaN
# ...

# %%
tb_data3.head()
# Out:
#    시군구별(1)  보험료분위별(1)      2013     2013.1    2013.2   2013.3     2013.4  \
# 0  시군구별(1)  보험료분위별(1)         계          계         계       직장         직장
# 1  시군구별(1)  보험료분위별(1)        소계         소계        소계       소계         소계
# 2  시군구별(1)  보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)
# 3       부산          계   1470147      84069   3239601   949213      84722
# 4       부산        1분위    144546      18183    233790    96767      24148
#
#      2013.5   2013.6     2013.7  ...    2019.5   2019.6     2019.7    2019.8  \
# 0        직장       직장         직장  ...        직장       직장         직장        직장
# 1        소계      근로자        근로자  ...        소계      근로자        근로자       근로자
# 2  적용인구 (명)  가입자 (명)  평균보험료 (원)  ...  적용인구 (명)  가입자 (명)  평균보험료 (원)  적용인구 (명)
# 3   2211363   866071      80514  ...   2202642  1005698     105419   2002128
# 4    179738    96372      24148  ...    194121   122965      31801    193728
#
#     2019.9    2019.10   2019.11   2019.12    2019.13   2019.14
# ...

# %%
tb_data4.head()
# Out:
#    시군구별(1)  보험료분위별(1)      2013     2013.1    2013.2   2013.3     2013.4  \
# 0  시군구별(1)  보험료분위별(1)         계          계         계       직장         직장
# 1  시군구별(1)  보험료분위별(1)        소계         소계        소계       소계         소계
# 2  시군구별(1)  보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)
# 3       서울          계   4579723     100737   9866346  3031907     102221
# 4       서울        1분위    389771      19281    662783   292254      23787
#
#      2013.5   2013.6     2013.7  ...    2019.5   2019.6     2019.7    2019.8  \
# 0        직장       직장         직장  ...        직장       직장         직장        직장
# 1        소계      근로자        근로자  ...        소계      근로자        근로자       근로자
# 2  적용인구 (명)  가입자 (명)  평균보험료 (원)  ...  적용인구 (명)  가입자 (명)  평균보험료 (원)  적용인구 (명)
# 3   6910081  2797708      99294  ...   6897961  3342210     125537   6380273
# 4    548074   291037      23787  ...    585037   374094      31324    584215
#
#     2019.9    2019.10   2019.11   2019.12    2019.13   2019.14
# ...

# %%
tb_data1.columns
# Out:
# Index(['시군구별(1)', '보험료분위별(1)', '2013', '2013.1', '2013.2', '2013.3', '2013.4',
#        '2013.5', '2013.6', '2013.7',
#        ...
#        '2019.5', '2019.6', '2019.7', '2019.8', '2019.9', '2019.10', '2019.11',
#        '2019.12', '2019.13', '2019.14'],
#       dtype='object', length=107)

# %%
tb_data1.loc[0]
# Out:
# 시군구별(1)        시군구별(1)
# 보험료분위별(1)    보험료분위별(1)
# 2013                 계
# 2013.1               계
# 2013.2               계
#                ...
# 2019.10             직장
# 2019.11             직장
# 2019.12             지역
# 2019.13             지역
# 2019.14             지역
# Name: 0, Length: 107, dtype: object

# %%
total_data = pd.DataFrame()

# %%
total_data = pd.concat([tb_data1, tb_data2, tb_data3, tb_data4])

# %%
total_data
# Out:
#     시군구별(1)  보험료분위별(1)      2013     2013.1    2013.2   2013.3     2013.4  \
# 0   시군구별(1)  보험료분위별(1)         계          계         계       직장         직장
# 1   시군구별(1)  보험료분위별(1)        소계         소계        소계       소계         소계
# 2   시군구별(1)  보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)
# 3        광주          계    588246      79882   1357778   384823      82390
# 4        광주        1분위     62886      18098    107772    41771      24564
# ..      ...        ...       ...        ...       ...      ...        ...
# 42       강원        6분위     57538      68714    129612    29887      69516
# 43       강원        7분위     53537      88757    130978    27230      85588
# 44       강원        8분위     47690     115137    127309    24994     108525
# 45       강원        9분위     47332     152530    144777    29339     145771
# 46       강원       10분위     37273     246699    117671    21745     243207
#
#       2013.5   2013.6     2013.7  ...   항목   단위 2013 년 2014 년 2015 년 2016 년  \
# ...

# %%
total_data["지역별 보험료 분위"] = total_data["시군구별(1)"] + total_data["보험료분위별(1)"]

# %%
total_data
# Out:
#     시군구별(1)  보험료분위별(1)      2013     2013.1    2013.2   2013.3     2013.4  \
# 0   시군구별(1)  보험료분위별(1)         계          계         계       직장         직장
# 1   시군구별(1)  보험료분위별(1)        소계         소계        소계       소계         소계
# 2   시군구별(1)  보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)
# 3        광주          계    588246      79882   1357778   384823      82390
# 4        광주        1분위     62886      18098    107772    41771      24564
# ..      ...        ...       ...        ...       ...      ...        ...
# 42       강원        6분위     57538      68714    129612    29887      69516
# 43       강원        7분위     53537      88757    130978    27230      85588
# 44       강원        8분위     47690     115137    127309    24994     108525
# 45       강원        9분위     47332     152530    144777    29339     145771
# 46       강원       10분위     37273     246699    117671    21745     243207
#
#       2013.5   2013.6     2013.7  ...   단위 2013 년 2014 년 2015 년 2016 년 2017 년  \
# ...

# %%
total_data.drop("시군구별(1)", axis=1, inplace=True)
total_data.drop("보험료분위별(1)", axis=1, inplace=True)

# %%
total_data
# Out:
#         2013     2013.1    2013.2   2013.3     2013.4    2013.5   2013.6  \
# 0          계          계         계       직장         직장        직장       직장
# 1         소계         소계        소계       소계         소계        소계      근로자
# 2   세대수 (세대)  평균보험료 (원)  적용인구 (명)  가입자 (명)  평균보험료 (원)  적용인구 (명)  가입자 (명)
# 3     588246      79882   1357778   384823      82390    965256   340452
# 4      62886      18098    107772    41771      24564     84898    41501
# ..       ...        ...       ...      ...        ...       ...      ...
# 42     57538      68714    129612    29887      69516     68285    27584
# 43     53537      88757    130978    27230      85588     69277    23170
# 44     47690     115137    127309    24994     108525     73211    18654
# 45     47332     152530    144777    29339     145771     99619    17468
# 46     37273     246699    117671    21745     243207     76853    15596
#
#        2013.7    2013.8   2013.9  ...   단위 2013 년 2014 년 2015 년 2016 년 2017 년  \
# ...

# %%
total_data.columns
# Out:
# Index(['2013', '2013.1', '2013.2', '2013.3', '2013.4', '2013.5', '2013.6',
#        '2013.7', '2013.8', '2013.9',
#        ...
#        '단위', '2013 년', '2014 년', '2015 년', '2016 년', '2017 년', '2018 년',
#        '2019 년', 'Unnamed: 12', '지역별 보험료 분위'],
#       dtype='object', length=119)

# %%
total_data = total_data[['지역별 보험료 분위', 
                         '2013', '2013.1', '2013.2', 
                         '2014', '2014.1', '2014.2', 
                         '2015', '2015.1', '2015.2', 
                         '2016', '2016.1', '2016.2', 
                         '2017', '2017.1', '2017.2', 
                         '2018', '2018.1', '2018.2', 
                         '2019', '2019.1', '2019.2', 
                        ]]

# %%
total_data
# Out:
#           지역별 보험료 분위      2013     2013.1    2013.2      2014     2014.1  \
# 0   시군구별(1)보험료분위별(1)         계          계         계         계          계
# 1   시군구별(1)보험료분위별(1)        소계         소계        소계        소계         소계
# 2   시군구별(1)보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  세대수 (세대)  평균보험료 (원)
# 3                광주계    588246      79882   1357778    602837      84576
# 4              광주1분위     62886      18098    107772     62207      18111
# ..               ...       ...        ...       ...       ...        ...
# 42             강원6분위     57538      68714    129612     59590      71564
# 43             강원7분위     53537      88757    130978     56877      92254
# 44             강원8분위     47690     115137    127309     53598     119625
# 45             강원9분위     47332     152530    144777     55592     157908
# 46            강원10분위     37273     246699    117671     40434     259830
#
#       2014.2      2015     2015.1    2015.2  ...    2016.2      2017  \
# ...

# %%
total_data.drop(0, inplace = True)
total_data.drop(1, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
total_data
# Out:
#           지역별 보험료 분위      2013     2013.1    2013.2      2014     2014.1  \
# 2   시군구별(1)보험료분위별(1)  세대수 (세대)  평균보험료 (원)  적용인구 (명)  세대수 (세대)  평균보험료 (원)
# 3                광주계    588246      79882   1357778    602837      84576
# 4              광주1분위     62886      18098    107772     62207      18111
# 5              광주2분위     75689      26033    130082     83235      26400
# 6              광주3분위     61421      32820    107653     59258      35984
# ..               ...       ...        ...       ...       ...        ...
# 42             강원6분위     57538      68714    129612     59590      71564
# 43             강원7분위     53537      88757    130978     56877      92254
# 44             강원8분위     47690     115137    127309     53598     119625
# 45             강원9분위     47332     152530    144777     55592     157908
# 46            강원10분위     37273     246699    117671     40434     259830
#
#       2014.2      2015     2015.1    2015.2  ...    2016.2      2017  \
# ...

# %%
new_namedic = {}
for i in range(len(total_data.columns)): 
    new_name = total_data.columns[i].split('.')[0] + "년 " + total_data.iloc[0][i]
    if i == 0:
        new_name = total_data.columns[i]
    new_namedic[total_data.columns[i]] = new_name
    
total_data.rename(columns=new_namedic, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
total_data
# Out:
#           지역별 보험료 분위 2013년 세대수 (세대) 2013년 평균보험료 (원) 2013년 적용인구 (명)  \
# 2   시군구별(1)보험료분위별(1)       세대수 (세대)       평균보험료 (원)       적용인구 (명)
# 3                광주계         588246           79882        1357778
# 4              광주1분위          62886           18098         107772
# 5              광주2분위          75689           26033         130082
# 6              광주3분위          61421           32820         107653
# ..               ...            ...             ...            ...
# 42             강원6분위          57538           68714         129612
# 43             강원7분위          53537           88757         130978
# 44             강원8분위          47690          115137         127309
# 45             강원9분위          47332          152530         144777
# 46            강원10분위          37273          246699         117671
#
#    2014년 세대수 (세대) 2014년 평균보험료 (원) 2014년 적용인구 (명) 2015년 세대수 (세대)  \
# 2        세대수 (세대)       평균보험료 (원)       적용인구 (명)       세대수 (세대)
# ...

# %%
total_data.drop(2, inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
total_data
# Out:
#    지역별 보험료 분위 2013년 세대수 (세대) 2013년 평균보험료 (원) 2013년 적용인구 (명) 2014년 세대수 (세대)  \
# 3         광주계         588246           79882        1357778         602837
# 4       광주1분위          62886           18098         107772          62207
# 5       광주2분위          75689           26033         130082          83235
# 6       광주3분위          61421           32820         107653          59258
# 7       광주4분위          55131           42684         107919          55473
# ..        ...            ...             ...            ...            ...
# 42      강원6분위          57538           68714         129612          59590
# 43      강원7분위          53537           88757         130978          56877
# 44      강원8분위          47690          115137         127309          53598
# 45      강원9분위          47332          152530         144777          55592
# 46     강원10분위          37273          246699         117671          40434
#
#    2014년 평균보험료 (원) 2014년 적용인구 (명) 2015년 세대수 (세대) 2015년 평균보험료 (원)  \
# ...

# %%
total_data.reset_index(drop=True, inplace=True)

# %%
total_data
# Out:
#      지역별 보험료 분위 2013년 세대수 (세대) 2013년 평균보험료 (원) 2013년 적용인구 (명) 2014년 세대수 (세대)  \
# 0           광주계         588246           79882        1357778         602837
# 1         광주1분위          62886           18098         107772          62207
# 2         광주2분위          75689           26033         130082          83235
# 3         광주3분위          61421           32820         107653          59258
# 4         광주4분위          55131           42684         107919          55473
# ...         ...            ...             ...            ...            ...
# 6735      강원6분위          57538           68714         129612          59590
# 6736      강원7분위          53537           88757         130978          56877
# 6737      강원8분위          47690          115137         127309          53598
# 6738      강원9분위          47332          152530         144777          55592
# 6739     강원10분위          37273          246699         117671          40434
#
# ...

# %%
total_data.to_csv("../Data/가구_Data/시군구별 건강보험료(13-19).csv")
