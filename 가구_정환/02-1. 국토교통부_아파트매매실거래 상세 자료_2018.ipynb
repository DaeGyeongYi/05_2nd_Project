# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
df_lawd_cd = pd.read_csv('../Data/법정동_Data/법정동코드+시군구코드.csv')

# %%
df_lawd_cd
# Out:
#      Unnamed: 0  시도코드    시군구코드          법정동명       법정동코드
# 0             0  11.0  11010.0     서울특별시 종로구  1111000000
# 1             1  11.0  11020.0      서울특별시 중구  1114000000
# 2             2  11.0  11030.0     서울특별시 용산구  1117000000
# 3             3  11.0  11040.0     서울특별시 성동구  1120000000
# 4             4  11.0  11050.0     서울특별시 광진구  1121500000
# ..          ...   ...      ...           ...         ...
# 224         224  38.0  38380.0      경상남도 함양군  4887000000
# 225         225  38.0  38390.0      경상남도 거창군  4888000000
# 226         226  38.0  38400.0      경상남도 합천군  4889000000
# 227         227  39.0  39010.0   제주특별자치도 제주시  5011000000
# 228         228  39.0  39020.0  제주특별자치도 서귀포시  5013000000
#
# [229 rows x 5 columns]

# %%
LAWD_CD_arr = df_lawd_cd['법정동코드'].apply(lambda x:str(x)[:5]).astype(str)

# %%
LAWD_CD_arr
# Out:
# 0      11110
# 1      11140
# 2      11170
# 3      11200
# 4      11215
#        ...
# 224    48870
# 225    48880
# 226    48890
# 227    50110
# 228    50130
# Name: 법정동코드, Length: 229, dtype: object

# %%
LAWD_CD_arr1 = LAWD_CD_arr[:75]
LAWD_CD_arr1
# Out:
# 0     11110
# 1     11140
# 2     11170
# 3     11200
# 4     11215
#       ...
# 70    31140
# 71    31170
# 72    31200
# 73    31710
# 74    36110
# Name: 법정동코드, Length: 75, dtype: object

# %%
LAWD_CD_arr2 = LAWD_CD_arr[75:150]
LAWD_CD_arr2
# Out:
# 75     41110
# 76     41130
# 77     41150
# 78     41170
# 79     41190
#        ...
# 145    44770
# 146    44790
# 147    44800
# 148    44810
# 149    44825
# Name: 법정동코드, Length: 75, dtype: object

# %%
len(LAWD_CD_arr2)
# Out:
# 75

# %%
LAWD_CD_arr3 = LAWD_CD_arr[150:]
LAWD_CD_arr3
# Out:
# 150    45110
# 151    45130
# 152    45140
# 153    45180
# 154    45190
#        ...
# 224    48870
# 225    48880
# 226    48890
# 227    50110
# 228    50130
# Name: 법정동코드, Length: 79, dtype: object

# %%
DEAL_YMD_arr = []
for m in range(1, 13):
        DEAL_YMD_arr.append(str(2017) + str(m).zfill(2))

# %%
DEAL_YMD_arr
# Out:
# ['201701',
#  '201702',
#  '201703',
#  '201704',
#  '201705',
#  '201706',
#  '201707',
#  '201708',
#  '201709',
#  '201710',
#  '201711',
#  '201712']

# %%
def create_dataframe_by_first(txt) : 
    df = pd.DataFrame()
    lis = re.split(r'[<>]', txt)    
    
    for i in range(1, len(lis), 2):
        df[lis[i].strip()] = ""
        
    return df

# %%
endpoint = 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?'
ServiceKey = '3V2Bs5v1nPXfnd%2BDk29h%2BF83ZwLTLf7cbMRiztm0Idr1fHxun3DzZiqxlKXXjRb8QpH9poo8NBizRLCgvUkQaA%3D%3D'

pageNo = '1'
numOfRows = '100'
LAWD_CD = '11110'
DEAL_YMD = '201701'

paramset = "serviceKey=" + ServiceKey +"&" \
            + "numOfRows=" + numOfRows +"&" \
            + "pageNo=" + pageNo +"&"  \
            + "numOfRows=" + numOfRows +"&"  \
            + "LAWD_CD=" + LAWD_CD + "&" \
            + "DEAL_YMD="+ DEAL_YMD

url = endpoint + paramset

result = requests.get(url)
bs_obj = BeautifulSoup(result.content, 'html.parser')

items = bs_obj.findAll('item')

df_apart_price_table = create_dataframe_by_first(items[0].text)

# %%
result
# Out:
# <Response [200]>

# %%
bs_obj
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultcode>00</resultcode><resultmsg>NORMAL SERVICE.</resultmsg></header><body><items><item>&lt;거래금액&gt;    67,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;사직로8길<!--도로명-->&lt;도로명건물본번호코드&gt;00004<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;03<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100135<!--도로명코드-->&lt;법정동&gt; 사직동<!--법정동-->&lt;법정동본번코드&gt;0009<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;11500<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;광화문풍림스페이스본(101동~105동)<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;9<!--일-->&lt;일련번호&gt;11110-2203<!--일련번호-->&lt;전용면적&gt;70.8<!--전용면적-->&lt;지번&gt;9<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;1<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item><item>&lt;거래금액&gt;    89,300<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;사직로8길<!--도로명-->&lt;도로명건물본번호코드&gt;00004<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;03<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100135<!--도로명코드-->&lt;법정동&gt; 사직동<!--법정동-->&lt;법정동본번코드&gt;0009<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;11500<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;광화문풍림스페이스본(101동~105동)<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;14<!--일-->&lt;일련번호&gt;11110-2203<!--일련번호-->&lt;전용면적&gt;94.51<!--전용면적-->&lt;지번&gt;9<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;8<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item><item>&lt;거래금액&gt;   110,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;사직로8길<!--도로명-->&lt;도로명건물본번호코드&gt;00004<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;03<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100135<!--도로명코드-->&lt;법정동&gt; 사직동<!--법정동-->&lt;법정동본번코드&gt;0009<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;11500<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;광화문풍림스페이스본(101동~105동)<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;16<!--일-->&lt;일련번호&gt;11110-2203<!--일련번호-->&lt;전용면적&gt;160.85<!--전용면적-->&lt;지번&gt;9<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;11<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item><item>&lt;거래금액&gt;    86,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;사직로8길<!--도로명-->&lt;도로명건물본번호코드&gt;00004<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;03<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100135<!--도로명코드-->&lt;법정동&gt; 사직동<!--법정동-->&lt;법정동본번코드&gt;0009<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;11500<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;광화문풍림스페이스본(101동~105동)<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;23<!--일-->&lt;일련번호&gt;11110-2203<!--일련번호-->&lt;전용면적&gt;94.51<!--전용면적-->&lt;지번&gt;9<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;6<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item><item>&lt;거래금액&gt;   117,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;사직로8길<!--도로명-->&lt;도로명건물본번호코드&gt;00004<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;03<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100135<!--도로명코드-->&lt;법정동&gt; 사직동<!--법정동-->&lt;법정동본번코드&gt;0009<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;11500<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;광화문풍림스페이스본(101동~105동)<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt
!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;인왕산아이파크<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;20<!--일-->&lt;일련번호&gt;11110-2212<!--일련번호-->&lt;전용면적&gt;59.993<!--전용면적-->&lt;지번&gt;60<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;11<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>,
#  <item>&lt;거래금액&gt;    66,990<!--거래금액-->&lt;건축년도&gt;2000<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;통일로<!--도로명-->&lt;도로명건물본번호코드&gt;00246<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00020<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;06<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;3000008<!--도로명코드-->&lt;법정동&gt; 무악동<!--법정동-->&lt;법정동본번코드&gt;0082<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;현대<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;21<!--일-->&lt;일련번호&gt;11110-90<!--일련번호-->&lt;전용면적&gt;114.9<!--전용면적-->&lt;지번&gt;82<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;7<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>,
#  <item>&lt;거래금액&gt;    71,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;통일로18길<!--도로명-->&lt;도로명건물본번호코드&gt;00009<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;01<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100482<!--도로명코드-->&lt;법정동&gt; 무악동<!--법정동-->&lt;법정동본번코드&gt;0060<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;인왕산아이파크<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;21<!--일-->&lt;일련번호&gt;11110-2212<!--일련번호-->&lt;전용면적&gt;114.931<!--전용면적-->&lt;지번&gt;60<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;1<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>,
#  <item>&lt;거래금액&gt;    49,790<!--거래금액-->&lt;건축년도&gt;2000<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;통일로<!--도로명-->&lt;도로명건물본번호코드&gt;00246<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00009<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;06<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;3000008<!--도로명코드-->&lt;법정동&gt; 무악동<!--법정동-->&lt;법정동본번코드&gt;0082<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;현대<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;24<!--일-->&lt;일련번호&gt;11110-90<!--일련번호-->&lt;전용면적&gt;60<!--전용면적-->&lt;지번&gt;82<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;11<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>,
#  <item>&lt;거래금액&gt;    48,990<!--거래금액-->&lt;건축년도&gt;2000<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;통일로<!--도로명-->&lt;도로명건물본번호코드&gt;00246<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00009<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;06<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;3000008<!--도로명코드-->&lt;법정동&gt; 무악동<!--법정동-->&lt;법정동본번코드&gt;0082<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;현대<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;24<!--일-->&lt;일련번호&gt;11110-90<!--일련번호-->&lt;전용면적&gt;60<!--전용면적-->&lt;지번&gt;82<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;9<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>,
#  <item>&lt;거래금액&gt;    66,000<!--거래금액-->&lt;건축년도&gt;2008<!--건축년도-->&lt;년&gt;2017<!--년-->&lt;도로명&gt;통일로18길<!--도로명-->&lt;도로명건물본번호코드&gt;00009<!--도로명건물본번호코드-->&lt;도로명건물부번호코드&gt;00000<!--도로명건물부번호코드-->&lt;도로명시군구코드&gt;11110<!--도로명시군구코드-->&lt;도로명일련번호코드&gt;01<!--도로명일련번호코드-->&lt;도로명지상지하코드&gt;0<!--도로명지상지하코드-->&lt;도로명코드&gt;4100482<!--도로명코드-->&lt;법정동&gt; 무악동<!--법정동-->&lt;법정동본번코드&gt;0060<!--법정동본번코드-->&lt;법정동부번코드&gt;0000<!--법정동부번코드-->&lt;법정동시군구코드&gt;11110<!--법정동시군구코드-->&lt;법정동읍면동코드&gt;18700<!--법정동읍면동코드-->&lt;법정동지번코드&gt;1<!--법정동지번코드-->&lt;아파트&gt;인왕산아이파크<!--아파트-->&lt;월&gt;1<!--월-->&lt;일&gt;31<!--일-->&lt;일련번호&gt;11110-2212<!--일련번호-->&lt;전용면적&gt;84.858<!--전용면적-->&lt;지번&gt;60<!--지번-->&lt;지역코드&gt;11110<!--지역코드-->&lt;층&gt;4<!--층-->&lt;해제사유발생일&gt; <!--해제사유발생일-->&lt;해제여부&gt; <!--해제여부--></item>]

# %%
df_apart_price_table
# Out:
# Empty DataFrame
# Columns: [거래금액, 건축년도, 년, 도로명, 도로명건물본번호코드, 도로명건물부번호코드, 도로명시군구코드, 도로명일련번호코드, 도로명지상지하코드, 도로명코드, 법정동, 법정동본번코드, 법정동부번코드, 법정동시군구코드, 법정동읍면동코드, 법정동지번코드, 아파트, 월, 일, 일련번호, 전용면적, 지번, 지역코드, 층, 해제사유발생일, 해제여부]
# Index: []
#
# [0 rows x 26 columns]

# %%
endpoint = 'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?'
ServiceKey = 'GuWr4NuVZZH2%2FIwkaH7Alaql4W2J7q5%2F57%2B66dUB8oiBxfAMTHBlctE64zKrxGPX3F5xsIzT96qgOEMmeP6Cxw%3D%3D'
cnt = 0
default_pageNo = '1'
default_numOfRows = '9999'

pageNo = default_pageNo
numOfRows = default_numOfRows


for ymd_param in DEAL_YMD_arr:
    DEAL_YMD = ymd_param
    # LAWD_CD_arr1 or LAWD_CD_arr2 or LAWD_CD_arr3
    for lawd_param in LAWD_CD_arr3:
        LAWD_CD = lawd_param
        
        df_apart_price_table = pd.DataFrame(df_apart_price_table.columns)

        paramset = "serviceKey=" + ServiceKey +"&" \
            + "pageNo=" + pageNo +"&"  \
            + "numOfRows=" + numOfRows +"&" \
            + "LAWD_CD=" + LAWD_CD + "&" \
            + "DEAL_YMD="+ DEAL_YMD
        
        url = endpoint + paramset
        
        result = requests.get(url)
        bs_obj = BeautifulSoup(result.content, 'html.parser')
                
        items = bs_obj.findAll('item')   
        
        to = bs_obj.findAll('totalcount')
        try:
            if (int(to[0].text) > 1000) : 
                print(DEAL_YMD + ", " + LAWD_CD)
        except:
            cnt += 1
            print("error")
        for itm in items:
            dlis = re.split(r'[<>]', itm.text)
            ddic = {}
            for i in range(1, len(dlis), 2):
                ddic[dlis[i].strip()] = dlis[i+1].strip()
            df_apart_price_table = df_apart_price_table.append(ddic, ignore_index=True)
        
        df_apart_price_table.to_csv("../Data/가구_Data/raw_Data/아파트매매데이터/아파트" + DEAL_YMD + "," + LAWD_CD + ".csv")
# Out:
# 201708, 48250
# 201709, 46230

# %%
# DEAL_YMD

# %%
# LAWD_CD

# %%
# df_apart_price_table

# %%
# df_apart_price_table.tail(30)

# %%
# df_apart_price_table.groupby(["도로명시군구코드"]).count()

# %%
# df_apart_price_table[df_apart_price_table["도로명시군구코드"] == '11230'].tail()

# %%
# df_apart_price_table.head(1)

# %%
# 데이터가 너무 많아서 현재 다 못받아온 상황 
# DEAL_YMD = '201612'
# LAWD_CD = '34040' 
# 부터 다시 받아서 ..?? 음.... 

# df_apart_price_table.to_csv("../Data/가구_Data/아파트매매실거래 상세 자료_2017.csv")
# df_apart_price_table.to_csv("../Data/가구_Data/아파트매매실거래 상세 자료_2017(2).csv")
