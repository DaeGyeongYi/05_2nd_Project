# %%
import pandas as pd

# %%
sub =pd.read_csv('최종본_전국지하철역목록.csv' index_col=None)
# Out:
#   File "<ipython-input-12-3f1b65ae9a06>", line 1
#     sub =pd.read_csv('최종본_전국지하철역목록.csv' index_col=None)
#                                         ^
# SyntaxError: invalid syntax

# %%
sub[sub.duplicated(['역사명'])]
# Out:
#       Unnamed: 0   역번호    역사명   노선번호          노선명 환승역구분       환승노선번호  \
# 11            11  0201     시청  S1102  서울 도시철도 2호선   환승역        S1101
# 56            56  0246    신설동  S1102  서울 도시철도 2호선   환승역        S1101
# 71            71  0319   종로3가  S1103  서울 도시철도 3호선   환승역  S1101+S1105
# 72            72  0320  을지로3가  S1103  서울 도시철도 3호선   환승역        S1102
# 82            82  0330     교대  S1103  서울 도시철도 3호선   환승역        S1103
# ...          ...   ...    ...    ...          ...   ...          ...
# 995          995  U123     어룡  L4101       의정부경전철   일반역            -
# 997          997  U124     송산  L4101       의정부경전철   일반역          NaN
# 999          999  U125     탑석  L4101       의정부경전철   일반역            -
# 1000        1000  Y110    기흥역  T4101         에버라인   환승역         K237
# 1004        1004  Y114    동백역  T4101         에버라인   일반역          NaN
#
#                         환승노선명        역위도         역경도          주소  시도코드  시군구코드  \
# ...
